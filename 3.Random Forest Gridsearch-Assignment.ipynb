# %%
# Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# open a Dataset

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#Remove the categorical data (i.e str change into numbers)

# %%
dataset= pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
# Split the Input  Output dataes

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independant=dataset[['age','bmi', 'children','sex_male','smoker_yes']]

# %%
independant
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependant= dataset[['charges']]

# %%
dependant
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
# Model creation from Test data

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squarded_error','absolute_error','poission''mae','friendman_mse'],'max_features':['auto','sqrt','log2'],'n_estimators':[10,100]}

grid= GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# Fitting the Model for grid seach                 
grid.fit(independant,dependant)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 100 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'friedman_mse', 'absolute_error', 'squared_error', 'poisson'}. Got 'squarded_error' instead.
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'friedman_mse', 'poisson', 'squared_error'}. Got 'squarded_error' instead.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'squared_error', 'absolute_error', 'friedman_mse'}. Got 'squarded_error' instead.
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'squared_error', 'friedman_mse', 'poisson'}. Got 'squarded_error' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'friedman_mse', 'absolute_error', 'squared_error', 'poisson'}. Got 'poissionmae' instead.
#
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'friedman_mse', 'absolute_error', 'squared_error', 'poisson'}. Got 'friendman_mse' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan 0.81075292 0.83328256 0.82077352 0.8321089
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squarded_error', 'absolute_error',
#                                        'poissionmae', 'friendman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after turning
# print(grid_best_params_)

# %%
re=grid.cv_results_
print("The r_score_value for best parameters:",format(grid.best_params_))
# Out:
# The r_score_value for best parameters: {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.010793      0.011099         0.000000        0.000000
# 1        0.008195      0.006427         0.000000        0.000000
# 2        0.006596      0.003004         0.000000        0.000000
# 3        0.009098      0.004126         0.000000        0.000000
# 4        0.005597      0.002936         0.000000        0.000000
# 5        0.005597      0.004221         0.000000        0.000000
# 6        0.002999      0.000002         0.000000        0.000000
# 7        0.003397      0.000491         0.000000        0.000000
# 8        0.612576      0.282475         0.009409        0.000195
# 9        2.788073      0.268621         0.033802        0.005657
# 10       0.284440      0.038131         0.014104        0.008711
# 11       2.488182      0.436530         0.033105        0.012373
# 12       0.003198      0.000400         0.000000        0.000000
# 13       0.002998      0.000894         0.000000        0.000000
# 14       0.002609      0.000498         0.000000        0.000000
# 15       0.002995      0.000002         0.000000        0.000000
# 16       0.003396      0.000490         0.000000        0.000000
# 17       0.004197      0.000979         0.000000        0.000000
# 18       0.004698      0.000744         0.000000        0.000000
# 19       0.004598      0.000492         0.000000        0.000000
# 20       0.004912      0.001136         0.000000        0.000000
# 21       0.004404      0.000856         0.000000        0.000000
# 22       0.003997      0.000632         0.000000        0.000000
# 23       0.004099      0.000665         0.000000        0.000000
#
#    param_criterion param_max_features param_n_estimators  \
# 0   squarded_error               auto                 10
# 1   squarded_error               auto                100
# 2   squarded_error               sqrt                 10
# 3   squarded_error               sqrt                100
# 4   squarded_error               log2                 10
# 5   squarded_error               log2                100
# 6   absolute_error               auto                 10
# 7   absolute_error               auto                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
# 12     poissionmae               auto                 10
# 13     poissionmae               auto                100
# 14     poissionmae               sqrt                 10
# 15     poissionmae               sqrt                100
# 16     poissionmae               log2                 10
# 17     poissionmae               log2                100
# 18   friendman_mse               auto                 10
# 19   friendman_mse               auto                100
# 20   friendman_mse               sqrt                 10
# 21   friendman_mse               sqrt                100
# 22   friendman_mse               log2                 10
# 23   friendman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squarded_error', 'max_features'...                NaN
# 1   {'criterion': 'squarded_error', 'max_features'...                NaN
# 2   {'criterion': 'squarded_error', 'max_features'...                NaN
# 3   {'criterion': 'squarded_error', 'max_features'...                NaN
# 4   {'criterion': 'squarded_error', 'max_features'...                NaN
# 5   {'criterion': 'squarded_error', 'max_features'...                NaN
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.848367
# 9   {'criterion': 'absolute_error', 'max_features'...           0.859370
# 10  {'criterion': 'absolute_error', 'max_features'...           0.850474
# 11  {'criterion': 'absolute_error', 'max_features'...           0.855817
# 12  {'criterion': 'poissionmae', 'max_features': '...                NaN
# 13  {'criterion': 'poissionmae', 'max_features': '...                NaN
# 14  {'criterion': 'poissionmae', 'max_features': '...                NaN
# 15  {'criterion': 'poissionmae', 'max_features': '...                NaN
# 16  {'criterion': 'poissionmae', 'max_features': '...                NaN
# 17  {'criterion': 'poissionmae', 'max_features': '...                NaN
# 18  {'criterion': 'friendman_mse', 'max_features':...                NaN
# 19  {'criterion': 'friendman_mse', 'max_features':...                NaN
# 20  {'criterion': 'friendman_mse', 'max_features':...                NaN
# 21  {'criterion': 'friendman_mse', 'max_features':...                NaN
# 22  {'criterion': 'friendman_mse', 'max_features':...                NaN
# 23  {'criterion': 'friendman_mse', 'max_features':...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.744967           0.820418           0.807626
# 9            0.782318           0.855273           0.827680
# 10           0.774466           0.839476           0.813899
# 11           0.778394           0.858639           0.825588
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                5
# 1                 NaN              NaN             NaN                5
# 2                 NaN              NaN             NaN                5
# 3                 NaN              NaN             NaN                5
# 4                 NaN              NaN             NaN                5
# 5                 NaN              NaN             NaN                5
# 6                 NaN              NaN             NaN                5
# 7                 NaN              NaN             NaN                5
# 8            0.832387         0.810753        0.035535                4
# 9            0.841772         0.833283        0.027803                1
# 10           0.825552         0.820774        0.026254                3
# 11           0.842106         0.832109        0.029304                2
# 12                NaN              NaN             NaN                5
# 13                NaN              NaN             NaN                5
# 14                NaN              NaN             NaN                5
# 15                NaN              NaN             NaN                5
# 16                NaN              NaN             NaN                5
# 17                NaN              NaN             NaN                5
# 18                NaN              NaN             NaN                5
# 19                NaN              NaN             NaN                5
# 20                NaN              NaN             NaN                5
# 21                NaN              NaN             NaN                5
# 22                NaN              NaN             NaN                5
# 23                NaN              NaN             NaN                5

# %%
age_input=float(input("Age:"))
bmi_input=float(input("bmi:"))
children_input=float(input("Children"))
sex_male_input=int(input("Sex_Male 0 or 1 :"))
smoker_input= int(input("Smoker Yes 0 to 1 :"))
# Out:
# Age: 32
# bmi: 43
# Children 2
# Sex_Male 0 or 1 : 0
# Smoker Yes 0 to 1 : 1

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_input]])
print("Future_Prediction-",format(Future_prediction))
# Out:
# Future_Prediction- [43077.0424587]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
