# %%
#Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Open the dataset

# %%
dataset= pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#Remove the catagorical data (Converting str to Numbers)

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#Splite input & Out put data set

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age','bmi','children','sex_male','smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
# Model creation-Train set

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid= {'kernel':['rbf','ploy','sigmoid','linear'],'C':[10,100,1000,2000,3000],'gamma':['auti','scale']}
grid= GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)

# Fitting the Model for grid seach                 
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 125 fits failed out of a total of 200.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 17 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'gamma' parameter of SVR must be a str among {'scale', 'auto'} or a float in the range [0.0, inf). Got 'auti' instead.
#
# --------------------------------------------------------------------------------
# 83 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'gamma' parameter of SVR must be a str among {'auto', 'scale'} or a float in the range [0.0, inf). Got 'auti' instead.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'sigmoid', 'poly', 'rbf', 'linear', 'precomputed'} or a callable. Got 'ploy' instead.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'rbf', 'sigmoid', 'precomputed', 'linear', 'poly'} or a callable. Got 'ploy' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'linear', 'precomputed', 'sigmoid', 'rbf', 'poly'} or a callable. Got 'ploy' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'poly', 'linear', 'rbf', 'sigmoid', 'precomputed'} or a callable. Got 'ploy' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [            nan             nan             nan             nan
#  -1.01276198e-01             nan -1.07639026e-01 -6.08619573e-03
#              nan             nan             nan             nan
#  -1.47633859e-01             nan -1.37843088e-01  5.35224744e-01
#              nan             nan             nan             nan
#  -1.44192504e-01             nan -2.21544064e+00  6.93778215e-01
#              nan             nan             nan             nan
#  -1.33399856e-01             nan -7.78112551e+00  6.86466564e-01
#              nan             nan             nan             nan
#  -1.20018116e-01             nan -1.69838559e+01  6.73913747e-01]
#   warnings.warn(
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auti', 'scale'],
#                          'kernel': ['rbf', 'ploy', 'sigmoid', 'linear']},
#              verbose=3)

# %%
# print best parameter after turning
# print(grid_best_params_)

# %%
re=grid.cv_results_
print("The r_score_value for best parameters:",format(grid.best_params_))
# Out:
# The r_score_value for best parameters: {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.003501  1.177008e-03         0.000000        0.000000      10
# 1        0.003398  4.892599e-04         0.000000        0.000000      10
# 2        0.005197  2.480671e-03         0.000000        0.000000      10
# 3        0.003797  9.804080e-04         0.000000        0.000000      10
# 4        0.480975  1.193070e-01         0.153304        0.018324      10
# 5        0.003598  4.904284e-04         0.000000        0.000000      10
# 6        0.287964  1.852832e-02         0.052607        0.004663      10
# 7        0.224232  1.957755e-02         0.029610        0.003979      10
# 8        0.002701  3.984179e-04         0.000000        0.000000     100
# 9        0.002405  3.758041e-04         0.000000        0.000000     100
# 10       0.003198  4.005203e-04         0.000000        0.000000     100
# 11       0.003399  4.902527e-04         0.000000        0.000000     100
# 12       0.233068  6.706368e-03         0.192905        0.054141     100
# 13       0.003198  9.794151e-04         0.000000        0.000000     100
# 14       0.302531  6.297758e-02         0.065113        0.013749     100
# 15       0.861277  3.447584e-01         0.064117        0.039512     100
# 16       0.003107  1.017103e-03         0.000000        0.000000    1000
# 17       0.002996  6.343722e-04         0.000000        0.000000    1000
# 18       0.002800  6.832527e-04         0.000000        0.000000    1000
# 19       0.003196  7.506256e-04         0.000000        0.000000    1000
# 20       0.421868  1.832949e-01         0.190543        0.106917    1000
# 21       0.005797  2.038642e-03         0.000000        0.000000    1000
# 22       0.496198  2.333479e-01         0.088909        0.046155    1000
# 23       2.569818  4.261951e-01         0.051120        0.032544    1000
# 24       0.002999  1.319728e-06         0.000000        0.000000    2000
# 25       0.002998  7.168434e-07         0.000000        0.000000    2000
# 26       0.003007  1.699080e-05         0.000000        0.000000    2000
# 27       0.002398  4.908578e-04         0.000000        0.000000    2000
# 28       0.450288  2.226934e-01         0.184654        0.094125    2000
# 29       0.007395  1.018357e-03         0.000000        0.000000    2000
# 30       0.458067  2.412076e-01         0.085859        0.059501    2000
# 31       4.730766  5.123594e-01         0.059771        0.025640    2000
# 32       0.006998  6.513261e-03         0.000000        0.000000    3000
# 33       0.003198  2.398086e-03         0.000000        0.000000    3000
# 34       0.005698  5.648671e-03         0.000000        0.000000    3000
# 35       0.004099  2.729309e-03         0.000000        0.000000    3000
# 36       0.548454  2.612609e-01         0.291771        0.104917    3000
# 37       0.004101  4.864464e-04         0.000000        0.000000    3000
# 38       0.301630  4.085735e-02         0.052469        0.002526    3000
# 39       8.875894  2.423698e+00         0.059676        0.045772    3000
#
#    param_gamma param_kernel  \
# 0         auti          rbf
# 1         auti         ploy
# 2         auti      sigmoid
# 3         auti       linear
# 4        scale          rbf
# 5        scale         ploy
# 6        scale      sigmoid
# 7        scale       linear
# 8         auti          rbf
# 9         auti         ploy
# 10        auti      sigmoid
# 11        auti       linear
# 12       scale          rbf
# 13       scale         ploy
# 14       scale      sigmoid
# 15       scale       linear
# 16        auti          rbf
# 17        auti         ploy
# 18        auti      sigmoid
# 19        auti       linear
# 20       scale          rbf
# 21       scale         ploy
# 22       scale      sigmoid
# 23       scale       linear
# 24        auti          rbf
# 25        auti         ploy
# 26        auti      sigmoid
# 27        auti       linear
# 28       scale          rbf
# 29       scale         ploy
# 30       scale      sigmoid
# 31       scale       linear
# 32        auti          rbf
# 33        auti         ploy
# 34        auti      sigmoid
# 35        auti       linear
# 36       scale          rbf
# 37       scale         ploy
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auti', 'kernel': 'rbf'}                NaN
# 1        {'C': 10, 'gamma': 'auti', 'kernel': 'ploy'}                NaN
# 2     {'C': 10, 'gamma': 'auti', 'kernel': 'sigmoid'}                NaN
# 3      {'C': 10, 'gamma': 'auti', 'kernel': 'linear'}                NaN
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.110409
# 5       {'C': 10, 'gamma': 'scale', 'kernel': 'ploy'}                NaN
# 6    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.116743
# 7     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.018943
# 8        {'C': 100, 'gamma': 'auti', 'kernel': 'rbf'}                NaN
# 9       {'C': 100, 'gamma': 'auti', 'kernel': 'ploy'}                NaN
# 10   {'C': 100, 'gamma': 'auti', 'kernel': 'sigmoid'}                NaN
# 11    {'C': 100, 'gamma': 'auti', 'kernel': 'linear'}                NaN
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}          -0.160182
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'ploy'}                NaN
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.142455
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.559313
# 16      {'C': 1000, 'gamma': 'auti', 'kernel': 'rbf'}                NaN
# 17     {'C': 1000, 'gamma': 'auti', 'kernel': 'ploy'}                NaN
# 18  {'C': 1000, 'gamma': 'auti', 'kernel': 'sigmoid'}                NaN
# 19   {'C': 1000, 'gamma': 'auti', 'kernel': 'linear'}                NaN
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.155430
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'ploy'}                NaN
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...          -2.043140
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.736398
# 24      {'C': 2000, 'gamma': 'auti', 'kernel': 'rbf'}                NaN
# 25     {'C': 2000, 'gamma': 'auti', 'kernel': 'ploy'}                NaN
# 26  {'C': 2000, 'gamma': 'auti', 'kernel': 'sigmoid'}                NaN
# 27   {'C': 2000, 'gamma': 'auti', 'kernel': 'linear'}                NaN
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.143510
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'ploy'}                NaN
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -7.209317
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.682349
# 32      {'C': 3000, 'gamma': 'auti', 'kernel': 'rbf'}                NaN
# 33     {'C': 3000, 'gamma': 'auti', 'kernel': 'ploy'}                NaN
# 34  {'C': 3000, 'gamma': 'auti', 'kernel': 'sigmoid'}                NaN
# 35   {'C': 3000, 'gamma': 'auti', 'kernel': 'linear'}                NaN
# 36     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.128958
# 37    {'C': 3000, 'gamma': 'scale', 'kernel': 'ploy'}                NaN
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...         -15.561853
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.677778
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4           -0.097459          -0.074488          -0.099597
# 5                 NaN                NaN                NaN
# 6           -0.119312          -0.085214          -0.108210
# 7            0.029886           0.022167           0.003112
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12          -0.107253          -0.123430          -0.137753
# 13                NaN                NaN                NaN
# 14          -0.160831          -0.117544          -0.137984
# 15           0.521798           0.547691           0.538805
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20          -0.098267          -0.123724          -0.137137
# 21                NaN                NaN                NaN
# 22          -2.686121          -2.194563          -2.210858
# 23           0.675162           0.680002           0.699377
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26                NaN                NaN                NaN
# 27                NaN                NaN                NaN
# 28          -0.087595          -0.113312          -0.128591
# 29                NaN                NaN                NaN
# 30          -9.282940          -7.776578          -7.745074
# 31           0.630642           0.750714           0.646368
# 32                NaN                NaN                NaN
# 33                NaN                NaN                NaN
# 34                NaN                NaN                NaN
# 35                NaN                NaN                NaN
# 36          -0.075578          -0.100199          -0.116051
# 37                NaN                NaN                NaN
# 38         -20.498908         -17.095474         -16.750877
# 39           0.626814           0.732806           0.633479
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               16
# 1                 NaN              NaN             NaN               16
# 2                 NaN              NaN             NaN               16
# 3                 NaN              NaN             NaN               16
# 4           -0.124428        -0.101276        0.016459                6
# 5                 NaN              NaN             NaN               16
# 6           -0.108716        -0.107639        0.012029                7
# 7           -0.066653        -0.006086        0.034672                5
# 8                 NaN              NaN             NaN               16
# 9                 NaN              NaN             NaN               16
# 10                NaN              NaN             NaN               16
# 11                NaN              NaN             NaN               16
# 12          -0.209551        -0.147634        0.035511               12
# 13                NaN              NaN             NaN               16
# 14          -0.130402        -0.137843        0.014263               10
# 15           0.508518         0.535225        0.018122                4
# 16                NaN              NaN             NaN               16
# 17                NaN              NaN             NaN               16
# 18                NaN              NaN             NaN               16
# 19                NaN              NaN             NaN               16
# 20          -0.206405        -0.144193        0.036262               11
# 21                NaN              NaN             NaN               16
# 22          -1.942521        -2.215441        0.255409               13
# 23           0.677952         0.693778        0.022955                1
# 24                NaN              NaN             NaN               16
# 25                NaN              NaN             NaN               16
# 26                NaN              NaN             NaN               16
# 27                NaN              NaN             NaN               16
# 28          -0.193992        -0.133400        0.035492                9
# 29                NaN              NaN             NaN               16
# 30          -6.891719        -7.781126        0.821557               14
# 31           0.722261         0.686467        0.045056                2
# 32                NaN              NaN             NaN               16
# 33                NaN              NaN             NaN               16
# 34                NaN              NaN             NaN               16
# 35                NaN              NaN             NaN               16
# 36          -0.179304        -0.120018        0.034578                8
# 37                NaN              NaN             NaN               16
# 38         -15.012168       -16.983856        1.914783               15
# 39           0.698692         0.673914        0.039876                3

# %%
age_input=float(input("Age:"))
bmi_input=float(input("bmi:"))
children_input=float(input("Children"))
sex_male_input=int(input("Sex_Male 0 or 1 :"))
smoker_input= int(input("Smoker Yes 0 to 1 :"))
# Out:
# Age: 32
# bmi: 43
# Children 2
# Sex_Male 0 or 1 : 0
# Smoker Yes 0 to 1 : 1

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_input]])
print("Future_Prediction-",format(Future_prediction))
# Out:
# Future_Prediction- [30603.97370646]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
